# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision

# %% [markdown]
# # Part 3: Variational Autoencoders (VAE)
#
# For this part of the lab, you will implement a VAE. There is some code below which will help you run the learning procedure, however, you will need to complete the definition of the loss function. Start by implementing the encoder and decoder for the VAE. There is a diagram below illustrating what these architectures should look like.
#
# Let's start by loading the Fashion-MNIST dataset again and transforming the data to a flattened tensor.

# %% [markdown]
# ### Loading the Dataset

# %%
# %matplotlib inline

import torchvision
import torchvision.transforms as transforms

batch_size = 256
image_dim = 784 #flattened

# dataset construction
transform = transforms.Compose([
    transforms.ToTensor(), # convert to tensor
    transforms.Lambda(lambda x: x.view(image_dim)) # flatten into vector
    ])

train_set = torchvision.datasets.FashionMNIST(
    root='./data/FashionMNIST'
    ,train=True
    ,download=True
    ,transform=transform
)

train_loader = torch.utils.data.DataLoader(
    train_set, batch_size=batch_size
)

# %% [markdown]
# ## Build a Simple Variational Autoencoder
#
# <img src="http://comp6248.ecs.soton.ac.uk/labs/lab8/VAE_resized.png">

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from tqdm import tqdm
from itertools import chain

import numpy as np
import matplotlib.pyplot as plt

class Encoder(nn.Module):
    '''
    simple encoder with a single hidden dense layer
    and linear projections to the diag-Gauss parameters
    '''
    # YOUR CODE HERE
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(Encoder, self).__init__()
        self.linear1 = nn.Sequential(
                nn.Linear(input_dim, hidden_dim),
                nn.ReLU(True))
        
        self.linear2 = nn.Sequential(
            nn.Linear(hidden_dim, output_dim),
            nn.ReLU(True))
        
        self.linear3 = nn.Sequential(
            nn.Linear(hidden_dim, output_dim),
            nn.ReLU(True))
        
    def forward(self, x):
        
        x = self.linear1(x)
        mu = self.linear2(x)
        log_sigma = self.linear3(x)
        return mu, log_sigma
    #raise NotImplementedError()

class Decoder(nn.Module):
    '''
    simple decoder: single dense hidden layer followed by 
    output layer with a sigmoid to squish values
    '''
    # YOUR CODE HERE
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(Decoder, self).__init__()
        
        self.decoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(True),
            nn.Linear(hidden_dim, output_dim),
            nn.Sigmoid())

    def forward(self, x):
        
        x = self.decoder(x)
        return x
    #raise NotImplementedError()

# %% [markdown]
# ## You may complete the code below to test your implementation, or alternately, rewrite your own.
#
# #### Please ensure there are some reconstructed images drawn at the bottom of your submitted Juypter notebook to help with the marking process.

# %%
import matplotlib.gridspec as gridspec    
import os

# Sampling function (using the reparameterisation trick)
def sample(mu, log_sigma2):
    eps = torch.randn(mu.shape[0], mu.shape[1])
    return mu + torch.exp(log_sigma2 / 2) * eps


#parameters
batch_size = 256
embedding_dim = 2
enc_hidden_units = 512
dec_hidden_units = 512
nEpoch = 10

# construct the encoder, decoder and optimiser
enc = Encoder(image_dim, enc_hidden_units, embedding_dim)
dec = Decoder(embedding_dim, dec_hidden_units, image_dim)
optimizer = optim.Adam(chain(enc.parameters(), dec.parameters()), lr=1e-3)

# training loop
for epoch in range(nEpoch):
    losses = []
    trainloader = tqdm(train_loader)

    for i, data in enumerate(train_loader, 0):
        inputs, _ = data

        optimizer.zero_grad()

        mu, log_sigma2 = enc(inputs)
        z = sample(mu, log_sigma2)
        outputs = dec(z)

        # E[log P(X|z)] - as images are binary it makes most sense to use binary cross entropy
        # we need to be a little careful - by default torch averages over every observation 
        # (e.g. each  pixel in each image of each batch), whereas we want the average over entire
        # images instead
        
        #recon = F.binary_cross_entropy(outputs, inputs, size_average=False) / inputs.shape[0]
        recon = F.binary_cross_entropy(outputs, inputs, size_average=False) 
                        
        kl = 0 
        # kl = D_KL(Q(z|X) || P(z|X)) - calculate in closed form
        # Compute the term kl which is then added to the total loss
        # YOUR CODE HERE
        #raise NotImplementedError()\
        k1 = torch.exp(log_sigma2) + mu ** 2 - 1 - log_sigma2
        #print(k1)
        kl =  torch.sum(k1, dim = 1)
        #print(k1)
        kl = torch.sum(kl, dim = 0)
        
        loss = recon + kl
        loss.backward()
        optimizer.step()

        # keep track of the loss and update the stats
        losses.append(loss.item())
        trainloader.set_postfix(loss=np.mean(losses), epoch=epoch)

    
    ## Please display some of the generated images in the submitted Notebook
    # YOUR CODE HERE
result = outputs.detach()
for i in range(8):
  plt.subplot(int(str(24)+str(i+1)))
  plt.imshow(result[i].view(28,28), cmap=plt.get_cmap('gray'))

# show the plot
plt.show()
    #raise NotImplementedError()
# Out:
#   0%|          | 0/235 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.42e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.38e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.35e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.32e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.29e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.27e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.25e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.23e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.21e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.19e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.18e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=0, loss=1.16e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.15e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.14e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.14e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.13e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.12e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.11e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.11e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.1e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.1e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.09e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.09e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=0, loss=1.08e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.08e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.07e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.07e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.06e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.06e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.05e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.05e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.05e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.05e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.04e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.04e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.04e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=0, loss=1.03e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.03e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.03e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.03e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.02e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.02e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.02e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.02e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.02e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.01e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.01e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.01e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=0, loss=1.01e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=1.01e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=1.01e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=1e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=1e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=1e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=1e+5]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=9.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=9.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=9.96e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=9.95e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=9.94e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=0, loss=9.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.89e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.88e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.87e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.86e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.86e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.85e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.84e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.83e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.82e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.81e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=0, loss=9.8e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.8e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.79e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.79e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.78e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.77e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.76e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.76e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.75e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.74e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.73e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.73e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=0, loss=9.73e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.72e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.71e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.7e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.7e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.69e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.68e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.68e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.67e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.67e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.66e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.66e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=0, loss=9.65e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.65e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.64e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.64e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.64e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.63e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.63e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.63e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.62e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.61e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.61e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.61e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.6e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=0, loss=9.6e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.59e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.59e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.59e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.59e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.58e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.58e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.57e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.57e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.57e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.57e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.56e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=0, loss=9.56e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.55e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.55e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.55e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.54e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.54e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.53e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.53e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.53e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.53e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.52e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.52e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=0, loss=9.52e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.52e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.51e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.51e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.51e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.51e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.51e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.5e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.5e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.5e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.5e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.5e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=0, loss=9.49e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.49e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.49e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.48e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.48e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.48e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.48e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.47e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.47e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.47e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.47e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.46e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=0, loss=9.46e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.46e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.46e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.46e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.46e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.45e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.45e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.45e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.45e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.44e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.44e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.44e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=0, loss=9.44e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.44e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.44e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.44e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.43e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.43e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.43e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.43e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.43e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.42e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.42e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.42e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=0, loss=9.42e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.42e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.41e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.41e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.41e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.41e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.41e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.41e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.4e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.4e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.4e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.4e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=0, loss=9.4e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.4e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.4e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.39e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.39e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.39e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.39e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.39e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.39e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.39e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.38e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.38e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.38e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=0, loss=9.38e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.38e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.38e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.37e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.36e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=0, loss=9.35e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=0, loss=9.35e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=0, loss=9.35e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=0, loss=9.35e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=0, loss=9.33e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=9.2e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=9.1e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=9.08e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=8.99e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=9e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=8.96e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=9e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=9e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=9.02e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=9.02e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.07e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.07e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=1, loss=9.07e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.06e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.05e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.04e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=1, loss=9.03e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=1, loss=9.01e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=9.09e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=9e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=8.89e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=8.9e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=8.87e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=8.89e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=8.9e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:00<?, ?it/s, epoch=2, loss=8.93e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.93e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.94e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.95e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.95e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.96e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.96e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:01<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:02<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:03<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:04<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.96e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.97e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=2, loss=8.98e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=2, loss=8.99e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=2, loss=8.99e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=2, loss=8.99e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:05<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.9e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:06<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:07<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:08<?, ?it/s, epoch=9, loss=8.91e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:09<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:10<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:11<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:12<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:13<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:14<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:15<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:16<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:17<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:18<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:19<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:20<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:21<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:21<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:21<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:21<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:21<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:21<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:21<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:21<?, ?it/s, epoch=9, loss=8.92e+4]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/235 [00:21<?, ?it/s, epoch=9, loss=8.9e+4]
